# %% [markdown]
# <a href="https://colab.research.google.com/github/sj2609/Introduction-to-Computational-Statistics-and-Statistical-Learning/blob/main/sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# matplotlib is renamed as plt

# %%
ad_expense=[20,10,50,60]
sales=[500,780,950,1110]
plt.plot(ad_expense,sales)
plt.show()
